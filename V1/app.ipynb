# %%
from corpusGenerator import *
import ipywidgets as widgets

# %% [markdown]
# # Créer un nouveau Corpus

# %%
# Créer le widget Text
queryText = widgets.Text(
    placeholder='Recherche...',
    disabled=False   
)

# Afficher le widget
display(queryText)

# Créer le widget IntText
nIntText = widgets.IntText(
    description='Nombre article',
    disabled=False
)
display(nIntText)
# Out:
# Text(value='', placeholder='Recherche...')
# IntText(value=0, description='Nombre article')

# %%
# Récupérer la valeur du widget
query = queryText.value
nArticle = nIntText.value
print(query)
print(nArticle)
# Out:
# france
# 300

# %%
createCorpus(query, nArticle)

# %% [markdown]
# # Chargement du corpus

# %%
corpus_charge = Corpus('CorpusTest')
c = corpus_charge.load(query+'.pkl')
print(repr(c))
# Out:
# $\mathcal{S}$-adic characterization of minimal dendric shifts, par France Gheeraert Co-Auteurs : ['Julien Leroy']
#  Arxiv
# (final) Higgs results from LEP, par Ulrich Schwickerath Co-Auteurs : 0
#  Arxiv
# 26M - Peut on faire un bilan de santé librement ?, par NombrilDuMonde Nombre de commentaires :9
#  Reddit
# 39h sans RTT, par Sabageti Nombre de commentaires :2
#  Reddit
# 44Ti nucleosynthesis gamma-ray lines with SIMBOL-X, par M. Renaud Co-Auteurs : ['F. Lebrun', 'A. Decourchelle', 'R. Terrier', 'J. Ballet']
#  Arxiv
# [PC] Aide pour mon Pc., par InevitableEnergy8670 Nombre de commentaires :13
#  Reddit
# [slay the spire] la carte "cri de guerre", par Feeling-Echidna8312 Nombre de commentaires :10
#  Reddit
# [STEAM] Pas l'argent pour son anniversaire, sur quoi me rabattre ?, par Guylntown Nombre de commentaires :59
#  Reddit
# [Throw Away] Suis-je un alternant empoté ?, par Inside-Space-3486 Nombre de commentaires :38
#  Reddit
# A 2.4 - 12 microns spectrophotometric study with ISO of Cygnus X-3 in  quiescence, par Lydie Koch-Miramond Co-Auteurs : ["P'eter 'Abrah'am", 'Ya"el Fuchs', 'Jean-Marc Bonnet-Bidaud', 'Arnaud Claret']
#  Arxiv
# A Case study of light pollution in France after the change in  legislation, par N. Aksaker Co-Auteurs : ['S. K. Yerli', 'Z. Kurt', 'M. Bayazit', 'A. Aktay', 'M. A. Erdoğan']
#  Arxiv
# A complex surface admitting a strongly plurisubharmonic function but no  holomorphic functions, par Franc Forstnerič Co-Auteurs : 0
#  Arxiv
# A conjectural bound on the second Betti number for hyper-Kähler  manifolds, par Yoon-Joo Kim Co-Auteurs : ['Radu Laza']
#  Arxiv
# A Criticism on "A Mathematician's Apology" by G. H. Hardy, par Paulo Régis C. Ruffino Co-Auteurs : 0
#  Arxiv
# A data capture and production management tool for the assembly and  construction of the CMS detectors, par J-M Le Goff Co-Auteurs : ['J-P Vialle', 'A Bazan', 'T Le Flour', 'S Lieunard', 'D Rousset', 'R McClatchey', 'N Baker', 'H Heath', 'Z Kovacs', 'E Leonardi', 'G Barone', 'G Organtini']
#  Arxiv
# A Ferrand-Obata theorem for rank one parabolic geometries, par Charles Frances Co-Auteurs : 0
#  Arxiv
# A Fully Coupled Multi-Physics Model to Simulate Phase Change Memory  Operations in Ge-rich Ge$_2$Sb$_2$Te$_5$ Alloys, par Robin Miquel Co-Auteurs : ['Thomas Cabout', 'Olga Cueto', 'Benoît Sklénard', 'Mathis Plapp']
#  Arxiv
# A Generalization of the Brodsky-Lepage Formalism, par L. Houra-Yaou Co-Auteurs : ['P. Kessler', 'J. Parisi', 'F. Murgia', 'J. Hansson']
#  Arxiv
# A linear programming approach to general dataflow process network  verification and dimensioning, par Renaud Sirdey Co-Auteurs : ['Pascal Aubry']
#  Arxiv
# A mathematical explanation via "intelligent" PID controllers of the  strange ubiquity of PIDs, par Brigitte D'Andrea Novel Co-Auteurs : ['Michel Fliess', 'Cédric Join', 'Hugues Mounier', 'Bruno Steux']
#  Arxiv
# A multifractal random walk, par E. Bacry Co-Auteurs : ['J. Delour', 'J. F. Muzy']
#  Arxiv
# A Multipath Transport Protocol for Future Internet, par Bachir Chihani Co-Auteurs : ['Collange Denis']
#  Arxiv
# A new fractional model in Caputo sense for studying the dynamics of  COVID-19 spread in France, par Mahmoud H. A. Saleh Co-Auteurs : ['Tarek M. Abed-Elhameed']
#  Arxiv
# A one-channel conductor in an ohmic environment: mapping to a TLL and  full counting statistics, par Ines Safi Co-Auteurs : ['Hubert Saleur']
#  Arxiv
# A p-adic Shimura-Maass operator on Mumford curves, par Matteo Longo Co-Auteurs : 0
#  Arxiv
# A parabolic minimal surface in R3 intersects every nonflat properly  embedded minimal surface of bounded curvature, par Franc Forstneric Co-Auteurs : 0
#  Arxiv
# A properly embedded holomorphic disc in the ball with finite area and  dense boundary curve, par Franc Forstneric Co-Auteurs : 0
#  Arxiv
# A quasi-Kinnersley tetrad for the quasi-Kerr metric, par Frances White Co-Auteurs : 0
#  Arxiv
# A Review, Framework and R toolkit for Exploring, Evaluating, and  Comparing Visualizations, par Stephen L. France Co-Auteurs : ['Ulas Akkucuk']
#  Arxiv
# A sequent calculus with procedure calls, par Mahfuza Farooque Co-Auteurs : ['Stéphane Lengrand']
#  Arxiv
# A supervised clustering approach for fMRI-based inference of brain  states, par Vincent Michel Co-Auteurs : ['Alexandre Gramfort', 'Gaël Varoquaux', 'Evelyn Eger', 'Christine Keribin', 'Bertrand Thirion']
#  Arxiv
# A Visual Analytics Approach to Compare Propagation Models in Social  Networks, par Jason Vallet Co-Auteurs : ['Hélène Kirchner', 'Bruno Pinaud', 'Guy Melançon']
#  Arxiv
# A VM-Agnostic and Backwards Compatible Protected Modifier for  Dynamically-Typed Languages, par Iona Thomas Co-Auteurs : ['Vincent Aranega', 'Stéphane Ducasse', 'Guillermo Polito', 'Pablo Tesone']
#  Arxiv
# About pseudo-Riemannian Lichnerowicz conjecture, par Charles Frances Co-Auteurs : 0
#  Arxiv
# Absolute Branching Ratio of Beta-Delayed Gamma-Ray Emission of N18, par R. H. France III Co-Auteurs : ['Z. Zhao', 'M. Gai']
#  Arxiv
# Actions of semisimple Lie groups preserving a degenerate Riemannian  metric, par Esmaa Bekkara Co-Auteurs : ['Charles Frances', 'Abdelghani Zeghib']
#  Arxiv
# Ad Orientem: the Orientation of Gothic Cathedrals of France, par Amelia Carolina Sparavigna Co-Auteurs : 0
#  Arxiv
# After Sitges, par F. Richard Co-Auteurs : 0
#  Arxiv
# aimez vous manger du cheval ? j'ai l'impression d'être le seul dans toute mes connaissances. juste curieux !, par moisebucks Nombre de commentaires :230
#  Reddit
# Aircraft routing and crew pairing: updated algorithms at Air France, par Axel Parmentier Co-Auteurs : ['Frédéric Meunier']
#  Arxiv
# Algebraic Change-Point Detection, par Michel Fliess Co-Auteurs : ['Cédric Join', 'Mamadou Mboup']
#  Arxiv
# Aligning component upgrades, par Roberto Di Cosmo Co-Auteurs : ['Olivier Lhomme', 'Claude Michel']
#  Arxiv
# Alternative Restart Strategies for CMA-ES, par Ilya Loshchilov Co-Auteurs : ['Marc Schoenauer', 'Michèle Sebag']
#  Arxiv
# American here, why is there a misconception that French people are mean?, par Guilty_Pass_1758 Nombre de commentaires :392
#  Reddit
# Américain ici: Comme les Jeux Olympiques approchent, je veux que ma soirée de visionnage soit authentiquement française. Des suggestions?, par Some1inreallife Nombre de commentaires :286
#  Reddit
# An analysis of Coggia-Couvreur attack on Loidreau's rank-metric public  key encryption scheme in the general case, par Pierre Loidreau Co-Auteurs : ['Ba-Duc Pham']
#  Arxiv
# An interpolation theorem for proper holomorphic embeddings, par Franc Forstneric Co-Auteurs : ['Bjorn Ivarsson', 'Frank Kutzschebauch', 'Jasna Prezelj']
#  Arxiv
# An Optimised Flow for Futures: From Theory to Practice, par Nicolas Chappe Co-Auteurs : ['Ludovic Henrio', 'Amaury Maillé', 'Matthieu Moy', 'Hadrien Renaud']
#  Arxiv
# Analogies minus analogy test: measuring regularities in word embeddings, par Louis Fournier Co-Auteurs : ['Emmanuel Dupoux', 'Ewan Dunbar']
#  Arxiv
# Analyzing Flowgraphs with ATL, par Valerio Cosentino Co-Auteurs : ['Massimo Tisi', 'Fabian Büttner']
#  Arxiv
# Anciens anxieux/anxieuses sociaux, quel est le meilleur conseil qu’on vous ai donné ?, par Imaginary_Grape_2841 Nombre de commentaires :48
#  Reddit
# API design for machine learning software: experiences from the  scikit-learn project, par Lars Buitinck Co-Auteurs : ['Gilles Louppe', 'Mathieu Blondel', 'Fabian Pedregosa', 'Andreas Mueller', 'Olivier Grisel', 'Vlad Niculae', 'Peter Prettenhofer', 'Alexandre Gramfort', 'Jaques Grobler', 'Robert Layton', 'Jake Vanderplas', 'Arnaud Joly', 'Brian Holt', 'Gaël Varoquaux']
#  Arxiv
# Appartements en France, par TheKeisari Nombre de commentaires :6
#  Reddit
# Approximation diophantienne et distribution locale sur une surface  torique II, par Zhizhong Huang Co-Auteurs : 0
#  Arxiv
# Are X-ray flashes a peculiar class of (soft) gamma-ray bursts ?, par Frederic Daigne Co-Auteurs : ['Celine Barraud', 'Robert Mochkovitch']
#  Arxiv
# Arnaqué dans une boutique de réparation de téléphone, par Benoo007 Nombre de commentaires :9
#  Reddit
# ATLsc with partial observation, par François Laroussinie Co-Auteurs : ['Nicolas Markey', 'Arnaud Sangnier']
#  Arxiv
# Atmospheres from very low-mass stars to extrasolar planets, par France Allard Co-Auteurs : ['Derek Homeier']
#  Arxiv
# Audiophile : choix d'ampli et conseils pour la sono de mon séjour., par SynKaan Nombre de commentaires :11
#  Reddit
# Avez-vous peur de laisser vos fenêtres ouvertes la nuit ?, par neOwx Nombre de commentaires :69
#  Reddit
# Avoir des compétences sociales est tellement plus importants que je ne le pensais, par rianebn Nombre de commentaires :92
#  Reddit
# Azimuthal Correlations in Photon-Photon Collisions, par N. Arteaga Co-Auteurs : ['C. Carimalo', 'P. Kessler', 'S. Ong', 'O. Panella']
#  Arxiv
# Baisse des APL ?, par Illustrious-Date-780 Nombre de commentaires :5
#  Reddit
# Baugh-Wooley Multiplication for the RISCV Processor, par Franc Grootjen Co-Auteurs : ['Nikolai Schauer']
#  Arxiv
# Besoin d'aide pour amplifier mes B&W CDM2, par Cosmomauricio Nombre de commentaires :9
#  Reddit
# Besoin d'aide pour divorce., par Lalalalasnoopy Nombre de commentaires :6
#  Reddit
# Best French city to study in and meet new people?, par Alternative_Mail_176 Nombre de commentaires :25
#  Reddit
# Billet d'avion avec les chèques vacances, par Itchy-Problem-627 Nombre de commentaires :16
#  Reddit
# Blind separation of noisy Gaussian stationary sources. Application to  cosmic microwave background imaging, par Jean-Francois Cardoso Co-Auteurs : ['Hichem Snoussi', 'Jacques Delabrouille', 'Guillaume Patanchon']
#  Arxiv
# Bonjour à tous connaissez-vous un bon avocat ou un juriste svp?, par Memepoenreve Nombre de commentaires :35
#  Reddit
# bonjour! question regarding college tuition, par thebiggestIiar Nombre de commentaires :2
#  Reddit
# Borderline INFP raconte sa vie, par _xsgb Nombre de commentaires :12
#  Reddit
# Bridge-mediated Donor-Acceptor Effective Coupling: Exact theoretical  description, par D. J. Bicout Co-Auteurs : ['F. Varchon', 'E. Kats']
#  Arxiv
# Bug des caisses automatiques, par A_IST Nombre de commentaires :23
#  Reddit
# Camper-van Break-in, par Visualnspirer Nombre de commentaires :4
#  Reddit
# Cartan-Kähler Theory and Applications to Local Isometric and Conformal  Embedding, par Nabil Kahouadji Co-Auteurs : 0
#  Arxiv
# Casorati Determinant Solutions for the Discrete Painlevé-II Equation, par Kenji Kajiwara Co-Auteurs : ['Yasuhiro Ohta', 'Junkichi Satsuma', 'Basil Grammaticos', 'Alfred Ramani']
#  Arxiv
# Chanteurs Français ou chanteuses Françaises, par GrettoNicoletto Nombre de commentaires :15
#  Reddit
# Characterization of the first true coaxial 18-fold segmented n-type  prototype detector for the GERDA project, par I. Abt Co-Auteurs : ['A. Caldwell', 'D. Gutknecht', 'K. Kröninger', 'M. Lampert', 'X. Liu', 'B. Majorovits', 'D. Quirion', 'F. Stelzer', 'P. Wendling']
#  Arxiv
# Codage arithmetique pour la description d'une distribution, par Guilhem Coq Co-Auteurs : ['Olivier Alata', 'Marc Arnaudon', 'Christian Olivier']
#  Arxiv
# Cohomology of moduli spaces, par Frances Kirwan Co-Auteurs : 0
#  Arxiv
# Colis et douanes — légal ou arnaque ?, par What-a-blush Nombre de commentaires :15
#  Reddit
# Combining sparse grids, multilevel MC and QMC for elliptic PDEs with  random coefficients, par Michael B. Giles Co-Auteurs : ['Frances Y. Kuo', 'Ian H. Sloan']
#  Arxiv
# Combining Technical and Financial Impacts for Countermeasure Selection, par Gustavo Gonzalez-Granadillo Co-Auteurs : ['Christophe Ponchel', 'Gregory Blanc', 'Hervé Debar']
#  Arxiv
# Comment je suis sorti de l'addiction au téléphone., par GorillaNightmare Nombre de commentaires :97
#  Reddit
# Comment refuser le small talk ? Des gens comme moi ?, par Just_Alfalfa_670 Nombre de commentaires :45
#  Reddit
# Comment s'améliorer en programmation algorithmique ?, par Alps_Disastrous Nombre de commentaires :21
#  Reddit
# Comment éviter les problématiques de communication avec des collègues ?, par kelsier_night Nombre de commentaires :15
#  Reddit
# Comments on "Factors associated with the spatial heterogeneity of the  first wave of COVID-19 in France: a nationwide geo-epidemiological study" by  Gaudart et al, par José A. Ferreira Co-Auteurs : 0
#  Arxiv
# Comparison between purely statistical and multi-agent based ap-proaches  for occupant behaviour modeling in buildings, par Khadija Tijani Co-Auteurs : ['Ayesha Kashif', 'Stéphane Ploix', 'Benjamin Haas', 'Julie Dugdale']
#  Arxiv
# Comparison of cuprates and nuclear matter pairing properties. Quartet  (alpha-particle) condensation in nuclear systems, par P. Schuck Co-Auteurs : 0
#  Arxiv
# Complete sets of relations in the cohomology rings of moduli spaces of  holomorphic bundles and parabolic bundles over a Riemann surface, par Richard Earl Co-Auteurs : ['Frances Kirwan']
#  Arxiv
# Configuration réseau pour un routeur Mikrotik, par Alps_Disastrous Nombre de commentaires :9
#  Reddit
# Configurational Approaches to Urban Form: Empirical Test on the City of  Nice (France), par Giovanni Fusco Co-Auteurs : ['Michele Tirico']
#  Arxiv
# Conseil lecture code de calcul, par Zanshin87li210 Nombre de commentaires :11
#  Reddit
# Conseil légal - appartement en location sans isolation - quels recours ?, par Green_Tartiflette Nombre de commentaires :12
#  Reddit
# Conseils achat fer à souder, par SipoMaj Nombre de commentaires :25
#  Reddit
# Conseils pour CV, par Wikays Nombre de commentaires :3
#  Reddit
# Contract Aware Components, 10 years after, par Antoine Beugnard Co-Auteurs : ['Jean-Marc Jézéquel', 'Noël Plouzeau']
#  Arxiv
# Controllability of the bilinear Schrödinger equation with several  controls and application to a 3D molecule, par Ugo Boscain Co-Auteurs : ['Marco Caponigro', 'Mario Sigalotti']
#  Arxiv
# Cooperative emission in quantum plasmonic superradiance, par H. Varguet Co-Auteurs : ['S. Guérin', 'H. R. Jauslin', 'G.']
#  Arxiv
# Correct-by-design Control Synthesis for Multilevel Converters using  State Space Decomposition, par Gilles Feld Co-Auteurs : ['Laurent Fribourg', 'Denis Labrousse', 'Bertrand Revol', 'Romain Soulat']
#  Arxiv
# Counterfactual Causality from First Principles?, par Gregor Gössler Co-Auteurs : ['Oleg Sokolsky', 'Jean-Bernard Stefani']
#  Arxiv
# CP parameters of the B systems from Tevatron, par Sergey Burdin Co-Auteurs : 0
#  Arxiv
# CPF / Pôle emploi, par Negative-Cup-6240 Nombre de commentaires :2
#  Reddit
# Cryptanalysis of public-key cryptosystems that use subcodes of algebraic  geometry codes, par Alain Couvreur Co-Auteurs : ['Irene Márquez-Corbella', 'Ruud Pellikaan']
#  Arxiv
# CT moto, par PIGEONVERT Nombre de commentaires :9
#  Reddit
# Dame folle à l’aide, par Potential-Alarm9071 Nombre de commentaires :88
#  Reddit
# Dark Energy: Beyond General Relativity?, par David Polarski Co-Auteurs : 0
#  Arxiv
# Decorated proofs for computational effects: States, par Jean-Guillaume Dumas Co-Auteurs : ['Dominique Duval', 'Laurent Fousse', 'Jean-Claude Reynaud']
#  Arxiv
# Demander des conseils sur la situation du chauffage, par IntroductionOk9892 Nombre de commentaires :1
#  Reddit
# Design and expected performance of the ANTARES neutrino telescope, par F. Montanet Co-Auteurs : 0
#  Arxiv
# Detection of Change--Points in the Spectral Density. With Applications  to ECG Data, par Pierre R. Bertrand Co-Auteurs : ['Gilles Teyssière', 'Gil Boudet', 'Alain Chamoux']
#  Arxiv
# Deterministic Automata for Unordered Trees, par Adrien Boiret Co-Auteurs : ['Vincent Hugot', 'Joachim Niehren', 'Ralf Treinen']
#  Arxiv
# Dielectric constant of glasses: first observation of a two-dimensional  behavior, par F. Ladieu Co-Auteurs : ['J. Le Cochec', 'P. Pari', 'P. Trouslard', 'P. Ailloud']
#  Arxiv
# Diplôme d’école VS titre RNCP, par RandomMaleMammal Nombre de commentaires :12
#  Reddit
# Discrete Breathers and Energy Localization in Nonlinear Lattices, par T. Dauxois Co-Auteurs : ['M. Peyrard']
#  Arxiv
# Discussion of "Search for the Wreckage of Air France Flight AF 447", par A. H. Welsh Co-Auteurs : 0
#  Arxiv
# Distribution of Eigenvalues for the Modular Group, par E. Bogomolny Co-Auteurs : ['F. Leyvraz', 'C. Schmit']
#  Arxiv
# Divisors defined by noncritical functions, par Franc Forstneric Co-Auteurs : 0
#  Arxiv
# Do soda taxes affect the consumption and health of school-aged children?  Evidence from France and Hungary, par Selina Gangl Co-Auteurs : 0
#  Arxiv
# Double vol de paillasson, par Brifie Nombre de commentaires :16
#  Reddit
# Durée de vie d'un disque dur ?, par Zanshin87li210 Nombre de commentaires :25
#  Reddit
# Dégénerescence Locale des Transformations Conformes  pseudo-Riemanniennes, par Charles Frances Co-Auteurs : 0
#  Arxiv
# EDF Tarif Bleu ou Zen Flex, par InfamousRevolution62 Nombre de commentaires :2
#  Reddit
# Eisenstein Metrics, par Cameron Franc Co-Auteurs : 0
#  Arxiv
# Element Diffusion and Accretion in Metal Poor Stars, par Sylvie Vauclair Co-Auteurs : 0
#  Arxiv
# Embeddings of infinitely connected planar domains into C^2, par Franc Forstneric Co-Auteurs : ['Erlend Fornaess Wold']
#  Arxiv
# Encore une panne majeure pour Bouygues dans l'ouest ?, par Mika56 Nombre de commentaires :30
#  Reddit
# Energy redistribution between quasiparticles in mesoscopic silver wires, par F. Pierre Co-Auteurs : ['H. Pothier', 'D. Esteve', 'M. H. Devoret']
#  Arxiv
# Enseigner les équations chimiques aux enfants de 6 ans, par KlausWalz Nombre de commentaires :0
#  Reddit
# Envoyer un médicament par courrier, par perkunos7 Nombre de commentaires :13
#  Reddit
# est-ce que la France est en retard technologiquement?, par xhak Nombre de commentaires :45
#  Reddit
# Est-ce que ça vous fait penser à un symbole nazi ? Moi oui donc j'ai pas trop envie de le coudre mais si ça ce trouve y'a que moi qui pense à ça, par brundax Nombre de commentaires :50
#  Reddit
# Et vos vœux en carte..., par CommissionNo1761 Nombre de commentaires :8
#  Reddit
# Euclidean quadratic forms are ADC forms: A short proof, par France Dacar Co-Auteurs : 0
#  Arxiv
# Every bordered Riemann surface is a complete proper curve in a ball, par Antonio Alarcon Co-Auteurs : ['Franc Forstneric']
#  Arxiv
# Evidence for coeval Late Triassic terrestrial impacts from the  Rochechouart (France) meteorite crater, par Laurent Carporzen Co-Auteurs : ['Stuart A. Gilder']
#  Arxiv
# Evolving Genes to Balance a Pole, par Miguel Nicolau Co-Auteurs : ['Marc Schoenauer', 'W. Banzhaf']
#  Arxiv
# Exact Random Walk Distributions using Noncommutative Geometry, par Jean Bellissard Co-Auteurs : ['Carlos J Camacho', 'Armelle Barelli', 'Francisco Claro']
#  Arxiv
# Existe t'il un sub ou on parle entreprenariat, projet, ou on peut poser des questions et avoir un retour comme sur conseiljuridique ?, par imyaen- Nombre de commentaires :3
#  Reddit
# Experimental Comparisons of Derivative Free Optimization Algorithms, par Anne Auger Co-Auteurs : ['Nikolaus Hansen', 'Jorge M. Perez Zerpa', 'Raymond Ros', 'Marc Schoenauer']
#  Arxiv
# Exponential functionals of Brownian motion and disordered systems, par Alain Comtet Co-Auteurs : ['Cécile Monthus', 'Marc Yor']
#  Arxiv
# Extension of the Virasoro and Neveu-Schwartz algebras and generalized  Sturm-Liouville operators, par P. Marcel Co-Auteurs : ['V. Ovsienko', 'C. Roger']
#  Arxiv
# Extraction de concepts sous contraintes dans des données d'expression  de gènes, par Baptiste Jeudy Co-Auteurs : ['François Rioult']
#  Arxiv
# Fatou-Bieberbach domains in $\mathbb C^n\setminus\mathbb R^k$, par Franc Forstneric Co-Auteurs : ['Erlend Fornaess Wold']
#  Arxiv
# Fibrations and Stein Neighborhoods, par Franc Forstneric Co-Auteurs : ['Erlend Fornaess Wold']
#  Arxiv
# Finances personnelles et revenu en cas de mobilisation générale, par GurthNada Nombre de commentaires :5
#  Reddit
# First and second order optimality conditions for optimal control  problems of state constrained integral equations, par J. Frédéric Bonnans Co-Auteurs : ['Constanza De La Vega', 'Xavier Dupuis']
#  Arxiv
# Fixed Parameter Undecidability for Wang Tilesets, par Emmanuel Jeandel Co-Auteurs : ['Nicolas Rolin']
#  Arxiv
# Flexible Automatic Scheduling For Autonomous Telescopes: The MAJORDOME, par M. Bringer Co-Auteurs : ['M. Boer', 'C. Peignot', 'G. Fontan', 'C. Merce']
#  Arxiv
# Force-velocity relation and density profiles for biased diffusion in an  adsorbed monolayer, par O. Benichou Co-Auteurs : ['A. M. Cazabat', 'J. De Coninck', 'M. Moreau', 'G. Oshanin']
#  Arxiv
# Formal Modelling of Ontologies : An Event-B based Approach Using the  Rodin Platform, par Yamine Ait Ameur Co-Auteurs : ['Idir Ait Sadoune', 'Kahina Hacid', 'Linda Mohand Oussaid']
#  Arxiv
# Formes normales pour les champs conformes pseudo-riemanniens, par Charles Frances Co-Auteurs : ['Karin Melnick']
#  Arxiv
# Forum Libre - 2024-01-03, par AutoModerator Nombre de commentaires :146
#  Reddit
# Forum Libre - 2024-01-04, par AutoModerator Nombre de commentaires :217
#  Reddit
# Forum Libre - 2024-01-05, par AutoModerator Nombre de commentaires :226
#  Reddit
# Forum Libre - 2024-01-06, par AutoModerator Nombre de commentaires :79
#  Reddit
# Front form QED(3+1): The spin-multiplet structure of the positronium  spectrum at strong coupling, par U. Trittmann Co-Auteurs : 0
#  Arxiv
# Fundamental physics in observational cosmology, par Patrick Peter Co-Auteurs : 0
#  Arxiv
# Fusion11 Conference Summary, par Carlos A. Bertulani Co-Auteurs : 0
#  Arxiv
# Fuzziness versus probability again, par F. Jurkovic Co-Auteurs : 0
#  Arxiv
# Gaussian Mixture Regression model with logistic weights, a penalized  maximum likelihood approach, par Lucie Montuelle Co-Auteurs : ['Erwan Le Pennec', 'Serge Cohen']
#  Arxiv
# Generalized Wess-Zumino Consistency Conditions for Pure W_3 Gravity  Anomalies, par Paul Watts Co-Auteurs : 0
#  Arxiv
# Glueball plus Pion Production in Photon-Photon Collisions., par M. A. ICHOLA Co-Auteurs : ['J. PARISI']
#  Arxiv
# Government French website to check and verify companies data, par wildmuffincake420 Nombre de commentaires :4
#  Reddit
# Grocery store prices, par segboia Nombre de commentaires :6
#  Reddit
# Growth of three-dimensional structures by atomic deposition on surfaces  containing defects : simulations and theory, par Pablo Jensen Co-Auteurs : ['Hernán Larralde', 'Muriel Meunier', 'Alberto Pimpinelli']
#  Arxiv
# Guerlain s'amuse à arnaquer les gens avec de la "science quantique", par Septentrion56 Nombre de commentaires :177
#  Reddit
# Hanle effect in coherent backscattering, par G. Labeyrie Co-Auteurs : ['C. Miniatura', 'C. A. Mueller', 'O. Sigwarth', 'D. Delande', 'R. Kaiser']
#  Arxiv
# Help with Masters in France applications, par Desperate_Dingo_6625 Nombre de commentaires :3
#  Reddit
# Heures d'embouteillages à Lyon, par Misaw1 Nombre de commentaires :6
#  Reddit
# Hierarchical Location Service with Prediction in Mobile Ad-Hoc Networks, par Ebtisam Amar Co-Auteurs : ['Selma Boumerdassi', 'Éric Renault']
#  Arxiv
# High Temperature QCD, par Edmond Iancu Co-Auteurs : 0
#  Arxiv
# Holomorphic discs with dense images, par Franc Forstneric Co-Auteurs : ['Joerg Winkelmann']
#  Arxiv
# Holomorphic families of long C^2's, par Franc Forstneric Co-Auteurs : 0
#  Arxiv
# Holomorphic flexibility properties of complex manifolds, par Franc Forstneric Co-Auteurs : 0
#  Arxiv
# Hopf Algebras of Graphs, par Jean-Christophe Novelli Co-Auteurs : ['Jean-Yves Thibon', 'Nicolas M. Thiéry']
#  Arxiv
# Hotels en france, par HotellInsider Nombre de commentaires :1
#  Reddit
# How long delays impact TCP performance for a connectivity from Reunion  Island ?, par Réhan Noordally Co-Auteurs : ['Xavier Nicolay', 'Yassine Gangat', 'Pascal Anelli']
#  Arxiv
# Hyperbolic complex contact structures on $\mathbb{C}^{2n+1}$, par Franc Forstneric Co-Auteurs : 0
#  Arxiv
# Hyperbolicité des variétés complexes, par Erwan Rousseau Co-Auteurs : 0
#  Arxiv
# Hypergeometric series, modular linear differential equations, and  vector-valued modular forms, par Cameron Franc Co-Auteurs : ['Geoffrey Mason']
#  Arxiv
# ICDAR 2021 Competition on Historical Map Segmentation, par Joseph Chazalon Co-Auteurs : ['Edwin Carlinet', 'Yizi Chen', 'Julien Perret', 'Bertrand Duménieu', 'Clément Mallet', 'Thierry Géraud', 'Vincent Nguyen', 'Nam Nguyen', 'Josef Baloun', 'Ladislav Lenc', 'Pavel Král']
#  Arxiv
# Immersions of open Riemann surfaces into the Riemann sphere, par Franc Forstneric Co-Auteurs : 0
#  Arxiv
# immigrant japonais en France: quel image?, par gorudo- Nombre de commentaires :20
#  Reddit
# Impossible de se faire rembourser par Europe assistance, par PomegranateMain7704 Nombre de commentaires :2
#  Reddit
# Influence of Magnetic Field on Effective Electron-Electron Interactions  in a Copper Wire, par A. Anthore Co-Auteurs : ['F. Pierre', 'H. Pothier', 'D. Esteve', 'M. -H. Devoret']
#  Arxiv
# Inférences d'enfants, par Zanshin87li210 Nombre de commentaires :129
#  Reddit
# Integrability of anisotropic and homogeneous Universes in scalar-tensor  theory of gravitation, par Julien Larena Co-Auteurs : ['; Jerome Perez']
#  Arxiv
# Integrable Trilinear PDE's, par J. Hietarinta Co-Auteurs : ['B. Grammaticos', 'A. Ramani']
#  Arxiv
# Interval centred form for proving stability of non-linear discrete-time  systems, par Auguste Bourgois Co-Auteurs : ['Luc Jaulin']
#  Arxiv
# Inverser les paroles pour rendre une chanson "drole/toxique" ?, par Mortyff Nombre de commentaires :6
#  Reddit
# ISO's view of SS433 Jet Interactions with the Interstellar Medium, par Yael Fuchs Co-Auteurs : 0
#  Arxiv
# Isometry Group of Lorentz Manifolds: A Coarse Perspective, par Charles Frances Co-Auteurs : 0
#  Arxiv
# Isoperimetry and heat kernel decay on percolation clusters, par Pierre Mathieu Co-Auteurs : ['Elisabeth Remy']
#  Arxiv
# Je craque tous mes pantalons help, par Motor-Use-1517 Nombre de commentaires :152
#  Reddit
# Je pense à abandonner, par BullfrogPutrid6131 Nombre de commentaires :205
#  Reddit
# Je recherche un canal pour poser des questions sur l'électronique mécanique., par Money_Tomato1915 Nombre de commentaires :2
#  Reddit
# Je rentre d'un petit trail matinal et je crois avoir un début de toux, comment faire pour limiter les dégâts ?, par lainkapete Nombre de commentaires :16
#  Reddit
# Je sais pas quoi faire de ma vie pro, par Palgia Nombre de commentaires :7
#  Reddit
# Je suis allé 113 fois au cinéma en 2023 - AMA, par uglydoglol Nombre de commentaires :260
#  Reddit
# Je suis au bout du rouleau., par Degtyarev466 Nombre de commentaires :79
#  Reddit
# Je suis harcelé dans ma résidence, par Kitchen-Mechanic2529 Nombre de commentaires :66
#  Reddit
# Je suis sidérée par la facture de Gaz d’Engie, je n’allume pourtant pas beaucoup le chauffage, par ThatFreelancer Nombre de commentaires :11
#  Reddit
# Josep Borrell : "le Moyen-Orient pourrait s'embraser si le conflit à Gaza n'est pas résolu" | Euronews, par FrankyFourFingers56 Nombre de commentaires :58
#  Reddit
# J’ai une théorie qui expliquerait tout death note, par Illustrious-Meet-192 Nombre de commentaires :13
#  Reddit
# Key mechanistic features of swelling and blistering of  helium-ion-irradiated tungsten, par Frances I. Allen Co-Auteurs : ['Peter Hosemann', 'Mehdi Balooch']
#  Arxiv
# Kinematics and morphology of ionized gas in Hickson Compact Group 18, par H. Plana Co-Auteurs : ['P. Amram', 'C. Mendes de Oliveira', 'C. Balkowski']
#  Arxiv
# Kinetic energy change with doping upon superfluid condensation in high  temperature superconductors, par G. Deutscher Co-Auteurs : ['A. F. Santander-Syro', 'N. Bontemps']
#  Arxiv
# Kinetics of Anchoring of Polymer Chains on Substrates with Chemically  Active Sites, par G. Oshanin Co-Auteurs : ['S. Nechaev', 'A. M. Cazabat', 'M. Moreau']
#  Arxiv
# l'angoisse de mon anniversaire, par None Nombre de commentaires :23
#  Reddit
# La france comique sur reddit, ou est elle ?, par ClockNotionStudio Nombre de commentaires :4
#  Reddit
# La mafia vous donne 30€/mois, par Apopocalyps Nombre de commentaires :86
#  Reddit
# Lambda-inflation versus observations, par E. V. Mikheeva Co-Auteurs : 0
#  Arxiv
# Large-Scale Structures Behind the Milky Way from Near-IR Surveys, par R. C. Kraan-Korteweg Co-Auteurs : ['A. Schroeder', 'G. A. Mamon', 'S. Ruphy']
#  Arxiv
# Le niveau abyssal des débats sur les subs anglophones., par TremendousCook Nombre de commentaires :81
#  Reddit
# Le propriétaire du logement que je loue doit-il payer mes frais d'hébergement pendant des travaux ?, par Willa_ Nombre de commentaires :2
#  Reddit
# Le redoublement à l'école, un crime contre l'individu et une hérésie budgétaire, par Cartographer1941 Nombre de commentaires :2
#  Reddit
# Le secret de l'instruction, le secret le plus mal gardé de France ?, par BatRoyal488 Nombre de commentaires :7
#  Reddit
# Les connaissances de la toile, par Serge Abiteboul Co-Auteurs : 0
#  Arxiv
# Les films " Le hobbit " sont angoissants?, par Historical-Dot-9940 Nombre de commentaires :32
#  Reddit
# Licensié et un peu perdu... Des conseils ?, par kathiou Nombre de commentaires :27
#  Reddit
# LiquidXML: Adaptive XML Content Redistribution, par Jesús Camacho-Rodríguez Co-Auteurs : ['Asterios Katsifodimos', 'Ioana Manolescu', 'Alexandra Roatis']
#  Arxiv
# Local Dynamics of Conformal Vector Fields, par Charles Frances Co-Auteurs : 0
#  Arxiv
# Local Rules for Computable Planar Tilings, par Thomas Fernique Co-Auteurs : ['Mathieu Sablik']
#  Arxiv
# Long-range acceleration induced by a scalar field external to gravity  and the indication from Pioneer 10/11, Galileo and Ulysses Data, par J. P. Mbelek Co-Auteurs : ['M. Lachièze-Rey']
#  Arxiv
# Lorentz Dynamics on Closed 3-Manifolds, par Charles Frances Co-Auteurs : 0
#  Arxiv
# Lower bounds for topological complexity, par Aleksandra Franc Co-Auteurs : ['Petar Pavešić']
#  Arxiv
# M'inscrire à Bloctel a multiplié par 5 le nombre d'appels de démarchage, par JeanneD4Rk Nombre de commentaires :66
#  Reddit
# Machine Learning for Neuroimaging with Scikit-Learn, par Alexandre Abraham Co-Auteurs : ['Fabian Pedregosa', 'Michael Eickenberg', 'Philippe Gervais', 'Andreas Muller', 'Jean Kossaifi', 'Alexandre Gramfort', 'Bertrand Thirion', 'Gäel Varoquaux']
#  Arxiv
# MagSafe, par Koop26 Nombre de commentaires :2
#  Reddit
# Manifolds of holomorphic mappings from strongly pseudoconvex domains, par Franc Forstneric Co-Auteurs : 0
#  Arxiv
# Matrices coupled in a chain. I. Eigenvalue correlations, par B. Eynard Co-Auteurs : ['M. L. Mehta']
#  Arxiv
# Matrices coupled in a chain. II. Spacing functions, par G. Mahoux Co-Auteurs : ['M. L. Mehta', 'J. -M. Normand']
#  Arxiv
# Mean Field Game Approach to Bitcoin Mining, par Charles Bertucci Co-Auteurs : ['Louis Bertucci', 'Jean-Michel Lasry', 'Pierre-Louis Lions']
#  Arxiv
# Mechanization of Incidence Projective Geometry in Higher Dimensions, a  Combinatorial Approach, par Pascal Schreck Co-Auteurs : ['Nicolas Magaud', 'David Braun']
#  Arxiv
# Medica-Plus: a Micromegas-based proof-of-concept detector for  sub-becquerel tritium activity assessment at the service of oncological  research, par F. Jambon Co-Auteurs : ['S. Aune', 'P. Baron', 'T. Benoit', 'T. Bey', 'D. Desforge', 'E. Ferrer-Ribas', 'A. Grabas', 'M. Kebbiri', 'I. Mandjavidze', 'T. Papaevangelou', 'M. Riallot', 'M. Vandenbroucke', 'F. Beau', 'V. Dive', 'C. Malgorn', 'F. Malloggi', 'A. Rousselot', 'F. Carrel', 'M. Trocmé']
#  Arxiv
# Meilleur destination touristiques en Europe?, par Azimimaxx Nombre de commentaires :19
#  Reddit
# Meilleurs pantalon de rando, par Ark4ma Nombre de commentaires :16
#  Reddit
# Memory effects in classical and quantum mean-field disordered models, par Leticia Cugliandolo Co-Auteurs : ['Gustavo Lozano', 'Homero Lozza']
#  Arxiv
# Mercredi Tech - 2024-01-03, par ChuckMauriceFacts Nombre de commentaires :98
#  Reddit
# Mergelyan's and Arakelian's theorems for manifold-valued maps, par Franc Forstneric Co-Auteurs : 0
#  Arxiv
# Microwave probes Dipole Blockade and van der Waals Forces in a Cold  Rydberg Gas, par R. Celistrino Teixeira Co-Auteurs : ['C. Hermann-Avigliano', 'Thanh Long Nguyen', 'T. Cantat-Moltrecht', 'Jean-Michel Raimond', 'S. Haroche', 'S. Gleyzes', 'M. Brune']
#  Arxiv
# Minimal surfaces for undergraduates, par Franc Forstneric Co-Auteurs : 0
#  Arxiv
# Minimal surfaces in Euclidean spaces by way of complex analysis, par Franc Forstneric Co-Auteurs : 0
#  Arxiv
# Mirror thermal noise in laser interferometer gravitational wave  detectors operating at room and cryogenic temperature, par Janyce Franc Co-Auteurs : ['Nazario Morgado', 'Raffaele Flaminio', 'Ronny Nawrodt', 'Iain Martin', 'Liam Cunningham', 'Alan Cumming', 'Sheila Rowan', 'James Hough']
#  Arxiv
# Model Checking Vector Addition Systems with one zero-test, par Rémi Bonnet Co-Auteurs : ['Alain FInkel', 'Jérôme Leroux', 'Marc Zeitoun']
#  Arxiv
# Model independent reconstruction of impact parameter distributions for  intermediate energy heavy ion collisions, par INDRA Collaboration Co-Auteurs : ['J. D. Frankland', 'D. Gruyer', 'E. Bonnet', 'B. Borderie', 'R. Bougault', 'A. Chbihi', 'J. E. Ducret', 'D. Durand', 'Q. Fable', 'M. Henri', 'J. Lemarié', 'N. Le Neindre', 'I. Lombardo', 'O. Lopez', 'L. Manduci', 'M. Pârlog', 'J. Quicray', 'G. Verde', 'E. Vient', 'M. Vigilante']
#  Arxiv
# Moduli spaces of bundles over Riemann surfaces and the Yang-Mills  stratification revisited, par Frances Kirwan Co-Auteurs : 0
#  Arxiv
# Molecular Dynamics and Monte-Carlo Simulations of CoPt alloys, par Mohammed Allalen Co-Auteurs : 0
#  Arxiv
# Mon pere est une grosse m*rde, par TeacherOne1205 Nombre de commentaires :82
#  Reddit
# Most real analytic Cauchy-Riemann manifolds are nonalgebraizable, par Franc Forstneric Co-Auteurs : 0
#  Arxiv
# Multilevel domain decomposition for electronic structure calculations, par M. Barrault Co-Auteurs : ['E. Cances', 'W. W. Hager', 'C. Le Bris']
#  Arxiv
# Multiscale modeling of the elastic behavior of architectured and  nanostructured Cu-Nb composite wires, par T. Gu Co-Auteurs : ['O. Castelnau', 'S. Forest', 'E. Hervé-Luanco', 'F. Lecouturier', 'H. Proudhon', 'L. Thilly']
#  Arxiv
# Multivariable $(\varphi ,Γ)$-modules and Representations of  Products of Galois Groups: The Case of Imperfect Residue Field, par Jishnu Ray Co-Auteurs : ['Feng Wei', 'Gergely Zábrádi']
#  Arxiv
# Near-field properties of plasmonic nanostructures with high aspect ratio, par Y. Ould Agha Co-Auteurs : ['O. Demichel', 'C. Girard', 'A. Bouhelier', 'G. Colas des Francs']
#  Arxiv
# Necessary and sufficient condition for stability of generalized  expectation value, par Aziz El Kaabouchi Co-Auteurs : ['Sumiyoshi Abe']
#  Arxiv
# Neutrino oscillations and neutrinoless double-beta decay, par Carlo Giunti Co-Auteurs : 0
#  Arxiv
# New Algorithms for Combinations of Objectives using Separating Automata, par Ashwani Anand Co-Auteurs : ['Nathanaël Fijalkow', 'Aliénor Goubault-Larrecq', 'Jérôme Leroux', 'Pierre Ohlmann']
#  Arxiv
# New Incommensurate Elongated-Triangle Phase in Quartz, par P. Saint-Gregoire Co-Auteurs : ["I. Luk'yanchuk", 'E. Snoeck', 'C. Roucau', 'V. Janovec']
#  Arxiv
# New release of the ELODIE library: Version 3.1, par Ph. Prugniel Co-Auteurs : ['C. Soubiran', 'M. Koleva', 'D. Le Borgne']
#  Arxiv
# Nom de la phobie d'étaler de la crème sir son visage, par Charly_Ngals Nombre de commentaires :13
#  Reddit
# Non Proliferation of Preimages in Integrable Mappings, par B. Grammaticos Co-Auteurs : ['A. Ramani', 'K. M. Tamizhmani']
#  Arxiv
# Non-monotonic field-dependence of the ZFC magnetization peak in some  systems of magnetic nanoparticles, par R. Sappey Co-Auteurs : ['E. Vincent', 'N. Hadacek', '; F. Chaput', 'J. P. Boilot', '; D. Zins']
#  Arxiv
# Nouvel appartement en location et problèmes de plomberie/VMC, par chloratine Nombre de commentaires :13
#  Reddit
# Nuclear forces from chiral effective field theory: a primer, par Evgeny Epelbaum Co-Auteurs : 0
#  Arxiv
# Observation of soliton pulse compression in photonic crystal waveguides, par P. Colman Co-Auteurs : ['C. Husko', 'S. Combrié', 'I. Sagnes', 'C. W. Wong', 'A. De Rossi']
#  Arxiv
# Observation of the onset of strong scattering on high frequency acoustic  phonons in densified silica glass, par B. Ruffle Co-Auteurs : ['M. Foret', 'E. Courtens', 'R. Vacher', 'G. Monaco']
#  Arxiv
# Oka properties of groups of holomorphic and algebraic automorphisms of  complex affine space, par Franc Forstneric Co-Auteurs : ['Finnur Larusson']
#  Arxiv
# Oka tubes in holomorphic line bundles, par Franc Forstneric Co-Auteurs : ['Yuta Kusakabe']
#  Arxiv
# On a question of Mendès France on normal numbers, par Verónica Becher Co-Auteurs : ['Manfred G. Madritsch']
#  Arxiv
# On applications of Maupertuis-Jacobi correspondence for Hamiltonians  $F(x,|p|)$ in some 2-D stationary semiclassical problems, par S. Dobrokhotov Co-Auteurs : ['D. Minenkov', 'M. Rouleux']
#  Arxiv
# On complete intersections, par Franc Forstneric Co-Auteurs : 0
#  Arxiv
# On contractive projections in Hardy spaces, par Florence Lancien Co-Auteurs : ['Beata Randrianantoanina', 'Eric Ricard']
#  Arxiv
# On Infinitary Rational Relations and Borel Sets, par Olivier Finkel Co-Auteurs : 0
#  Arxiv
# On the Galactic aberration constant, par Z. Malkin Co-Auteurs : 0
#  Arxiv
# On the Hodge conjecture for $q$-complete manifolds, par Franc Forstneric Co-Auteurs : ['Jaka Smrekar', 'Alexandre Sukhov']
#  Arxiv
# On the stability of flow-aware CSMA, par T. Bonald Co-Auteurs : ['M. Feuillet']
#  Arxiv
# On two multistable extensions of stable Lévy motion and their  semimartingale representation, par Ronan Le Guével Co-Auteurs : ['Jacques Lévy-Vehel', 'Lining Liu']
#  Arxiv
# Où est-ce-que je peux apprendre le savoir vivre ?, par Trick_Advance2439 Nombre de commentaires :37
#  Reddit
# Où faire une permanente pour homme à Paris pour boucler ses cheveux ?, par BusyAmbassador Nombre de commentaires :3
#  Reddit
# Où réparer une chaise dont les soudures métal craquent ?, par faeliun Nombre de commentaires :6
#  Reddit
# p-adic vertex operator algebras, par Cameron Franc Co-Auteurs : ['Geoffrey Mason']
#  Arxiv
# Paradiseo: From a Modular Framework for Evolutionary Computation to the  Automated Design of Metaheuristics ---22 Years of Paradiseo---, par Johann Dreo Co-Auteurs : ['Arnaud Liefooghe', 'Sébastien Verel', 'Marc Schoenauer', 'Juan J. Merelo', 'Alexandre Quemy', 'Benjamin Bouvier', 'Jan Gmys']
#  Arxiv
# Parametric Potential Determination by the Canonical Function Method, par C. Tannous Co-Auteurs : ['K. Fakhreddine', 'J. Langlois']
#  Arxiv
# Performance of the LHC, ATLAS and CMS in 2011, par Daniel Fournier Co-Auteurs : 0
#  Arxiv
# Period of the gamma-ray staggering in the 150Gd superdeformed region, par D. Samsoen Co-Auteurs : ['P. Quentin', 'I. N. Mikhailov']
#  Arxiv
# Persistent currents in carbon nanotubes based rings, par S. Latil Co-Auteurs : ['S. Roche', 'A. Rubio']
#  Arxiv
# Petrov-Galerkin Finite Volumes, par François Dubois Co-Auteurs : 0
#  Arxiv
# Peut-on m'expliquer ce que fait la douane française ?, par TheLostSki Nombre de commentaires :23
#  Reddit
# Phenomenological analysis of the 2020 COVID-19 outbreak dynamics, par Borko Stosic Co-Auteurs : 0
#  Arxiv
# Phenomenological theory of friction in the quasistatic limit :  collective pinning and memory effects, par Lydéric Bocquet Co-Auteurs : ['Henrik Jeldtoft Jensen']
#  Arxiv
# Physics observables for color transparency, par Bernard Pire Co-Auteurs : 0
#  Arxiv
# Piscine au lycée, par Itchy-Entertainer-84 Nombre de commentaires :562
#  Reddit
# Pour 2024 je veux: des serviettes hygieniques fonctionnelles, par am_kassidi Nombre de commentaires :41
#  Reddit
# Pourquoi les Français ne parlent plus comme avant?, par depressionsucks67 Nombre de commentaires :511
#  Reddit
# Pourquoi les militaires revendent leurs couteaux en cette saison ?, par LittleOrsaySociety Nombre de commentaires :45
#  Reddit
# Pourquoi ne pas enseigner sa langue natale à son enfant ?, par Pretty-Stuff2397 Nombre de commentaires :159
#  Reddit
# Pourquoi ne pas utiliser les techniques actuelles de blockchain pour passer à la démocratie directe ?, par PrinceCorum13 Nombre de commentaires :94
#  Reddit
# Pourquoi sommes-nous si radins en France?, par GateauBananeAmandes Nombre de commentaires :68
#  Reddit
# Predicting academic success in Belgium and France Comparison and  integration of variables related to student behavior, par Thibaut Lust Co-Auteurs : ['Nadine Meskens', 'Mario Ahues']
#  Arxiv
# Predicting the Solar Potential of Rooftops using Image Segmentation and  Structured Data, par Daniel de Barros Soares Co-Auteurs : ['François Andrieux', 'Bastien Hell', 'Julien Lenhardt', 'Jordi Badosa', 'Sylvain Gavoille', 'Stéphane Gaiffas', 'Emmanuel Bacry']
#  Arxiv
# Preliminary remarks on option pricing and dynamic hedging, par Michel Fliess Co-Auteurs : ['Cédric Join']
#  Arxiv
# Proceedings International Workshop on Component and Service  Interoperability, par Javier Cámara Co-Auteurs : ['Carlos Canal', 'Gwen Salaün']
#  Arxiv
# Proceedings of the 15th Workshop on Logic-based methods in Programming  Environments WLPE'05 -- October 5, 2005 -- Sitges (Barcelona), Spain, par Alexander Serebrenik Co-Auteurs : ['Susana Munoz-Hernandez']
#  Arxiv
# Proceedings Thirteenth Workshop on Quantitative Aspects of Programming  Languages and Systems, par Nathalie Bertrand Co-Auteurs : ['Mirco Tribastone']
#  Arxiv
# Production of Meson Pairs Involving $L \neq 0$ Mesons in Photon-Photon  Collisions, par L. Houra-Yaou Co-Auteurs : ['P. Kessler', 'J. Parisi', 'F. Murgia', 'J. Hansson']
#  Arxiv
# Proper holomorphic embeddings into Stein manifolds with the density  property, par Rafael Andrist Co-Auteurs : ['Franc Forstneric', 'Tyson Ritter', 'Erlend Fornaess Wold']
#  Arxiv
# Proper holomorphic embeddings with small limit sets, par Franc Forstneric Co-Auteurs : 0
#  Arxiv
# Proper superminimal surfaces of given conformal types in the hyperbolic  four-space, par Franc Forstneric Co-Auteurs : 0
#  Arxiv
# Préparateur Pharmacie, par Jazzlike_Priority854 Nombre de commentaires :3
#  Reddit
# Prêt et création de monnaie, par JoyantLeBrave Nombre de commentaires :5
#  Reddit
# Pénurie d'augmentin, par jean-pat Nombre de commentaires :32
#  Reddit
# Qu'y a-t-il de beau en France ?, par NrkxF Nombre de commentaires :37
#  Reddit
# Quantum Calculation of Dipole Excitation in Fusion Reaction, par C. Simenel Co-Auteurs : ['Ph. Chomaz', 'G. de France']
#  Arxiv
# Que faire pour rendre son chômage inoubliable?, par GateauBananeAmandes Nombre de commentaires :20
#  Reddit
# Que pensez vous des frais de livraison à 3€ rendus obligatoire pour les livres (loi Darcos)?, par snipizgood Nombre de commentaires :470
#  Reddit
# Quel est l’équivalent du Monde Diplomatique pour les Sciences ?, par thepostmanpat Nombre de commentaires :13
#  Reddit
# Quelle est cette nouvelle mode à la con de mettre son clignotant à droite puis à gauche puis à droite dans un rond point quand on va tout droit?, par Popal24 Nombre de commentaires :75
#  Reddit
# Quelle type de rupture de contrat pour touché le chômage?, par Skylux31 Nombre de commentaires :14
#  Reddit
# Question droits de douane, par DokiDokiSymphony Nombre de commentaires :26
#  Reddit
# Question forum travail 😂, par Natsuu_22 Nombre de commentaires :3
#  Reddit
# Questions relatives au recyclage de nos biodéchets, par Viandox78 Nombre de commentaires :5
#  Reddit
# RAFALE FRENCH NAVY PILOTS - CHILLOUT 10, par Levagabondsolitaire Nombre de commentaires :10
#  Reddit
# Random walk on Bethe lattice and hyperbolic geometry, par Cecile Monthus Co-Auteurs : ['Chistophe Texier']
#  Arxiv
# Rapid variability of the kHz-QPO frequency in 4U1608-52, par S. Paltani Co-Auteurs : ['D. Barret', 'J. F. Olive', 'G. K. Skinner']
#  Arxiv
# Reachability Analysis of Communicating Pushdown Systems, par Alexander Heussner Co-Auteurs : ['Jérôme Leroux', 'Anca Muscholl', 'Grégoire Sutre']
#  Arxiv
# Realistic estimate of the Covid-19 incidence and mortality rate in  France, par Guillaume Malpuech Co-Auteurs : ['Anne Tournadre', 'Francois Berry', 'Laurent Gerbaud']
#  Arxiv
# Recent atmospheric neutrino results from Soudan 2, par T. Kafka Co-Auteurs : 0
#  Arxiv
# Recherche streaming/VOD/DL *Maria Schneider* réalisé par Elisabeth Surin en 1983, par where_is_the_salt Nombre de commentaires :5
#  Reddit
# Recommandations 😀, par the_potterhead_gurl Nombre de commentaires :6
#  Reddit
# Reconstructing sleptons in cascade-decays at the linear collider, par Mikael Berggren Co-Auteurs : 0
#  Arxiv
# Regional analysis of COVID-19 in France from fit of hospital data with  different evolutionary models, par Gary A. Mamon Co-Auteurs : 0
#  Arxiv
# Relativistic Bound States in 2+1 and 1+1 Dimensions in the Null-Plane, par J. P. B. C de Melo Co-Auteurs : ['A. E. A. Amorim', 'Lauro Tomio', 'T. Frederico']
#  Arxiv
# Removable and essential singular sets for higher dimensional conformal  maps, par Charles Frances Co-Auteurs : 0
#  Arxiv
# Renting outside Paris, par RamziMT Nombre de commentaires :0
#  Reddit
# Reproducing software environments: a prerequisite for reproducible  research, par Ludovic Courtès Co-Auteurs : 0
#  Arxiv
# Restricted Complexity, General Complexity, par Edgar Morin Co-Auteurs : 0
#  Arxiv
# Revenue des subs sur Twitch, par Macic1 Nombre de commentaires :14
#  Reddit
# Riemannian curvature: variations on different notions of positivity, par Mohammed Larbi Labbi Co-Auteurs : 0
#  Arxiv
# Rigidity at the boundary for conformal structures and other Cartan  geometries, par Charles Frances Co-Auteurs : 0
#  Arxiv
# Rocade ou périph ?, par Bratusse Nombre de commentaires :39
#  Reddit
# Runge approximation on convex sets implies the Oka property, par Franc Forstneric Co-Auteurs : 0
#  Arxiv
# Samedi Écriture - Sujet Libre ou "Vous rencontrez votre esprit totem", par WillWorkForCatGifs Nombre de commentaires :0
#  Reddit
# Scaling law for the critical function of an approximate renormalization, par C. Chandre Co-Auteurs : ['P. Moussa']
#  Arxiv
# Se regarder dans les yeux quand on trinque, par Ulzaf Nombre de commentaires :104
#  Reddit
# Second order scattering descriptors predict fMRI activity due to visual  textures, par Michael Eickenberg Co-Auteurs : ['Fabian Pedregosa', 'Senoussi Mehdi', 'Alexandre Gramfort', 'Bertrand Thirion']
#  Arxiv
# Service Client: Faut il mieux être sympa ou chiant/aggressif pour être compensé?, par Flamisus Nombre de commentaires :110
#  Reddit
# Severe Language Effect in University Rankings: Particularly Germany and  France are wronged in citation-based rankings, par Anthony F. J. van Raan Co-Auteurs : ['Thed N. van Leeuwen', 'Martijn S. Visser']
#  Arxiv
# si je suis renvoyé en France a 18 ans estce qu'il y aurai des aides ou associations pou m'aider ou je serai sans abris?, par le-roi-lucas Nombre de commentaires :39
#  Reddit
# SIMBOL-X : a new generation hard X-ray telescope, par P. Ferrando Co-Auteurs : ['M. Arnaud', 'B. Cordier', 'A. Goldwurm', 'O. Limousin', 'J. Paul', 'J. L. Sauvageot', 'P. O. Petrucci', 'M. Mouchet', 'G. Bignami', 'O. Citterio', 'S. Campana', 'G. Pareschi', 'G. Tagliaferri', 'U. Briel', 'G. Hasinger', 'L. Strueder', 'P. Lechner', 'E. Kendziorra', 'M. Turner']
#  Arxiv
# Single-particle spectra near a stripe instability, par S. Caprara Co-Auteurs : ['C. Di Castro', 'M. Grilli']
#  Arxiv
# Skiing in France, par RepeatPristine1790 Nombre de commentaires :13
#  Reddit
# SNCF tickets pricing. Nouveau en France, par Taboli Nombre de commentaires :3
#  Reddit
# Solving the 100 Swiss Francs Problem, par Mingfu Zhu Co-Auteurs : ['Guangran Jiang', 'Shuhong Gao']
#  Arxiv
# Some properties of morphic images of (eventually) dendric words, par France Gheeraert Co-Auteurs : 0
#  Arxiv
# Sos médecin, par CGandKat Nombre de commentaires :4
#  Reddit
# Sound modes broadening in quasicrystals, par M. de Boissieu Co-Auteurs : ['R. Currat', 'S. Francoual', 'E. Kats']
#  Arxiv
# Spaces with high topological complexity, par Aleksandra Franc Co-Auteurs : ['Petar Pavešić']
#  Arxiv
# Spin and Clifford algebras, an introduction, par Marc Lachieze-Rey Co-Auteurs : 0
#  Arxiv
# Spreading of Latex Particles on a Substrate, par A. W. C. Lau Co-Auteurs : ['M. Portigliatti', 'E. Raphael', 'L. Leger']
#  Arxiv
# Statistical properties of the 2D attached Rouse chain, par Olivier Benichou Co-Auteurs : ['Jean Desbois']
#  Arxiv
# Status of the MSW Solutions to the Solar Neutrino Problem, par M. C. Gonzalez-Garcia Co-Auteurs : ['C. Peña-Garay']
#  Arxiv
# Stein compacts in Levi-flat hypersurfaces, par Franc Forstneric Co-Auteurs : ['Christine Laurent-Thiebaut']
#  Arxiv
# Stein neighbourhoods of bordered complex curves attached to  holomorphically convex sets, par Franc Forstneric Co-Auteurs : 0
#  Arxiv
# Sticker Caillou dans les toilettes, par Ambitious_Dinner_572 Nombre de commentaires :16
#  Reddit
# Stochastic fuzzy controller, par Franc Jurkovic Co-Auteurs : 0
#  Arxiv
# Stock market crashes, Precursors and Replicas, par Didier Sornette Co-Auteurs : ['Anders Johansen', 'Jean-Philippe Bouchaud']
#  Arxiv
# String attractors of fixed points of k-bonacci-like morphisms, par France Gheeraert Co-Auteurs : ['Giuseppe Romana', 'Manon Stipulanti']
#  Arxiv
# Strongly pseudoconvex handlebodies, par Franc Forstneric Co-Auteurs : ['Jernej Kozak']
#  Arxiv
# Suggestions sur ce que je peux envoyer à ma sœur en France, par abdelbskoo Nombre de commentaires :13
#  Reddit
# suis-je le seul a en avoir marre d'entendre bernard gabay partout?, par Exciting_Company Nombre de commentaires :9
#  Reddit
# Suis-je le trou de balle : Accueillir un "plan cul" chez soi, par comptejetteauloins Nombre de commentaires :134
#  Reddit
# Suis-je malade ou est-ce normal ?, par ThisHat7115 Nombre de commentaires :64
#  Reddit
# Suis-je normal ?, par Stasialy Nombre de commentaires :48
#  Reddit
# Superconducting proximity effect in a mesoscopic ferromagnetic wire, par M. Giroud Co-Auteurs : ['H. Courtois', 'K. Hasselbach', 'D. Mailly', 'B. Pannetier']
#  Arxiv
# Supercooled liquids, the glass transition, and computer simulations, par Walter Kob Co-Auteurs : 0
#  Arxiv
# Supersonically Turbulent, Shock Bound Interaction Zones, par Doris Folini Co-Auteurs : ['Rolf Walder', 'Jean M. Favre']
#  Arxiv
# Surjective holomorphic maps onto Oka manifolds, par Franc Forstneric Co-Auteurs : 0
#  Arxiv
# SUSY searches at the Tevatron, par Michel Jaffré Co-Auteurs : 0
#  Arxiv
# Switching the magnetic configuration of a spin valve by current induced  domain wall motion, par J. Grollier Co-Auteurs : ['D. Lacour', 'V. Cros', 'A. Hamzic', 'A. Vaures', 'A. Fert', 'D. Adam', 'G. Faini']
#  Arxiv
# Symplectic implosion and non-reductive quotients, par Frances Kirwan Co-Auteurs : 0
#  Arxiv
# Synthesis in Presence of Dynamic Links, par Béatrice Bérard Co-Auteurs : ['Benedikt Bollig', 'Patricia Bouyer', 'Matthias Függer', 'Nathalie Sznajder']
#  Arxiv
# Systoles in translation surfaces, par Corentin Boissy Co-Auteurs : ['Slavyana Geninska']
#  Arxiv
# Séjour de 4-5 jours au ski, par badcaptain1129 Nombre de commentaires :14
#  Reddit
# Tagging and localisation of ionizing events using NbSi transition edge  phonon sensors for Dark Matter searches, par EDELWEISS Collaboration Co-Auteurs : ['C. Augier', 'A. Benoît', 'L. Bergé', 'J. Billard', 'A. Broniatowski', 'P. Camus', 'A. Cazes', 'M. Chapellier', 'F. Charlieux', 'J. Colas', 'M. De Jésus', 'L. Dumoulin', 'K. Eitel', 'J. B. Filippini', 'D. Filosofov', 'J. Gascon', 'A. Giuliani', 'M. Gros', 'E. Guy', 'Y. Jin', 'A. Juillard', 'H. Lattaud', 'S. Marnieros', 'N. Martini', 'X. -F. Navick', 'C. Nones', 'E. Olivieri', 'C. Oriol', 'P. Pari', 'B. Paul', 'D. Poda', 'A. Rojas', 'S. Rozov', 'V. Sanglard', 'L. Vagneron', 'E. Yakushev', 'A. Zolotarova', 'B. J. Kavanagh']
#  Arxiv
# TAROT: A status report, par Michel Boër Co-Auteurs : ['J. L. Atteia', 'M. Bringer', 'A. Klotz', 'C. Peignot', 'R. Malina', 'P. Sanchez', 'H. Pedersen', 'G. Calvet', 'J. Eysseric', 'A. Leroy', 'M. Meissonier', 'C. Pollas', 'J. de Freitas Pacheco']
#  Arxiv
# The BMV project: Search for photon oscillations into massive particles, par C. Robilliard Co-Auteurs : ['B. Pinto Da Souza', 'F. Bielsa', 'J. Mauchain', 'M. Nardone', 'G. Bailly', 'M. Fouché', 'R. Battesti', 'C. Rizzo']
#  Arxiv
# The Calabi-Yau problem for minimal surfaces with Cantor ends, par Franc Forstneric Co-Auteurs : 0
#  Arxiv
# The effect of a modulated flux on the growth of thin films, par Pablo Jensen Co-Auteurs : ['Bernd Niemeyer']
#  Arxiv
# The emergence of French statistics. How mathematics entered the world of  statistics in France during the 1920s, par Rémi Catellier Co-Auteurs : ['Laurent Mazliak']
#  Arxiv
# The first thirty years of Andersen-Lempert theory, par Franc Forstneric Co-Auteurs : ['Frank Kutzschebauch']
#  Arxiv
# The Galactic Center at High Energies, par A. Goldwurm Co-Auteurs : 0
#  Arxiv
# The Hodge Numbers of the Moduli Spaces of Vector Bundles over a Riemann  surface, par Richard Earl Co-Auteurs : ['Frances Kirwan']
#  Arxiv
# The homotopy principle in complex analysis: a survey, par Franc Forstneric Co-Auteurs : 0
#  Arxiv
# The Impact of the Chrono-geometrical Structure of Spacetime on Causality, par Eric Bois Co-Auteurs : ['Eric Trelut']
#  Arxiv
# The Last Passage Problem on Graphs, par Jean Desbois Co-Auteurs : ['Olivier Benichou']
#  Arxiv
# The master Painlevé VI heat equation, par Robert Conte Co-Auteurs : ['Ivan Dornic']
#  Arxiv
# The NIKA instrument: results and perspectives towards a permanent KID  based camera for the Pico Veleta observatory, par A. D'Addabbo Co-Auteurs : ['R. Adam', 'A. Adane', 'P. Ade', 'P. André', 'A. Beelen', 'B. Belier', 'A. Benoit', 'A. Bideaud', 'N. Billot', 'O. Bourrion', 'M. Calvo', 'A. Catalano', 'G. Coiffard', 'B. Comis', 'F. -X. Désert', 'S. Doyle', 'J. Goupy', 'C. Kramer', 'S. Leclercq', 'J. Macias-Perez', 'J. Martino', 'P. Mauskopf', 'F. Mayet', 'A. Monfardini', 'F. Pajot', 'E. Pascale', 'N. Ponthieu', 'V. Revéret', 'L. Rodriguez', 'G. Savini', 'K. F. Schuster', 'A. Sievers', 'C. Tucker', 'R. Zylka']
#  Arxiv
# The Oka principle, lifting of holomorphic maps and removability of  intersections, par Franc Forstneric Co-Auteurs : 0
#  Arxiv
# The origin of the strong soft excess and puzzling iron line complex in  Mkn 841, par P. O. Petrucci Co-Auteurs : ['G. Ponti', 'G. Matt', 'L. Maraschi', 'J. Malzac', 'M. Mouchet', 'C. Boisson', 'A. Longinotti', 'K. Nandra', 'P. Ferrando', 'G. Henri']
#  Arxiv
# The Physics of ELFE, par Bernard Pire Co-Auteurs : 0
#  Arxiv
# The Schur multiplier of finite symplectic groups, par Louis Funar Co-Auteurs : ['Wolfgang Pitsch']
#  Arxiv
# The Selection of Tenured Astronomers in France, par Gary A. Mamon Co-Auteurs : 0
#  Arxiv
# The SIRIUS Mixed analog-digital ASIC developed for the LOFT LAD and WFM  instruments, par A. Cros Co-Auteurs : ['D. Rambaud', 'E. Moutaye', 'L. Ravera', 'D. Barret', 'P. Caïs', 'R. Clédassou', 'P. Bodin', 'JY. Seyler', 'A. Bonzo', 'M. Feroci', 'C. Labanti', 'Y. Evangelista', 'Y. Favre']
#  Arxiv
# The Solar Neutrino Problem in the Light of a Violation of the  Equivalence Principle, par A. M. Gago Co-Auteurs : ['H. Nunokawa', 'R. Zukanovich Funchal']
#  Arxiv
# Thermalization of Squeezed States, par Allan I. Solomon Co-Auteurs : 0
#  Arxiv
# Three-dimensional imprimitive representations of the modular group and  their associated modular forms, par Cameron Franc Co-Auteurs : ['Geoffrey Mason']
#  Arxiv
# Time evolution in general gauge theories, par Robert Marnelius Co-Auteurs : 0
#  Arxiv
# Time-Varying Optimization: Algorithms and Engineering Applications, par Andrea Simonetto Co-Auteurs : 0
#  Arxiv
# Title Stabilization of Membrane Pores by Packing, par D. J. Bicout Co-Auteurs : ['F. Schmid', 'E. Kats']
#  Arxiv
# TOP 2014: Experimental Summary, par Christian Schwanenberger Co-Auteurs : 0
#  Arxiv
# Topological Analysis of Linear Polymer Melts, par Christos Tzoumanekas Co-Auteurs : ['Doros N. Theodorou']
#  Arxiv
# Topological arguments for Kolmogorov complexity, par Alexander Shen Co-Auteurs : ['Andrei Romashchenko']
#  Arxiv
# Topological complexity of the telescope, par Aleksandra Franc Co-Auteurs : 0
#  Arxiv
# Topological properties of cellular automata on trees, par Gabriele Fici Co-Auteurs : ['Francesca Fiorenzi']
#  Arxiv
# Travelling for six months. Medical preparation, par Mhaoilmhuire Nombre de commentaires :17
#  Reddit
# TREEWIDTH and PATHWIDTH parameterized by vertex cover, par Mathieu Chapelle Co-Auteurs : ['Mathieu Liedloff', 'Ioan Todinca', 'Yngve Villanger']
#  Arxiv
# Tri des déchets alimentaires biodégradables en 2024 : votre stratégie ?, par Looutre Nombre de commentaires :45
#  Reddit
# Trouver du travail comme clerc de notaire, par Initial-Distance9624 Nombre de commentaires :10
#  Reddit
# Two-Dimensional Navier-Stokes Simulation of Breaking Waves, par G. Chen Co-Auteurs : ['C. Kharif', 'S. Zaleski', 'J. Li']
#  Arxiv
# Two-dimensional S=1/2 antiferromagnet on a plaquette lattice, par S. V. Meshkov Co-Auteurs : ['D. Foerster']
#  Arxiv
# Télétravail, par flyolas Nombre de commentaires :2
#  Reddit
# Ultra High Energy Cosmic ray and gamma-ray signatures of inductive  acceleration in AGN jets, par Rachid Ouyed Co-Auteurs : ['Guenter Sigl', 'Maxim Lyutikov']
#  Arxiv
# Un bon site pour faire imprimer des hoodies de très bonne qualité?, par Hyakutak Nombre de commentaires :8
#  Reddit
# Un programme de jeux français/européen des années 2000., par Open-Ad914 Nombre de commentaires :2
#  Reddit
# Un sub d'informatique générale ?, par MrPassoir Nombre de commentaires :15
#  Reddit
# Use and usability in a digital library search system, par Robert K. France Co-Auteurs : ['Lucy Terry Nowell', 'Edward A. Fox', 'Rani A. Saad', 'Jianxin Zhao']
#  Arxiv
# Using Answer Set Programming in an Inference-Based approach to Natural  Language Semantics, par Farid Nouioua Co-Auteurs : ['Pascal Nicolas']
#  Arxiv
# Validation of an immersed boundary method for compressible flows, par Thomas Renaud Co-Auteurs : ['Christophe Benoit', 'Stephanie Péron', 'Ivan Mary', 'Nicolas Alferez']
#  Arxiv
# Variations on Gromov's open-dense orbit theorem, par Charles Frances Co-Auteurs : 0
#  Arxiv
# Vers une commande sans modèle pour aménagements hydroélectriques  en cascade, par Cédric Join Co-Auteurs : ['Gérard Robert', 'Michel Fliess']
#  Arxiv
# Vertige à cause des écrans (pc), par NorZ69190 Nombre de commentaires :46
#  Reddit
# Very high-energy gamma-ray sources as seen by the CAT imaging telescope, par F. Piron Co-Auteurs : 0
#  Arxiv
# Verysourd 2 : faut il payer, par ChampiLardon Nombre de commentaires :13
#  Reddit
# Vidéo déverrouillage haleine, par Angle_of-France Nombre de commentaires :2
#  Reddit
# Viré d'un chantier comme un malpropre, par JeanneD4Rk Nombre de commentaires :10
#  Reddit
# Visa, par Emotional-Can3115 Nombre de commentaires :2
#  Reddit
# Volatility made observable at last, par Michel Fliess Co-Auteurs : ['Cédric Join', 'Frédéric Hatt']
#  Arxiv
# VRAI OU FAUX. Les images des premiers pas de l’homme sur la lune ont-elles été trafiquées ?, par stephlo74 Nombre de commentaires :36
#  Reddit
# Wake effects characterization using wake oscillator model. Comparison on  2D response with experiments, par Benoît Gaurier Co-Auteurs : ['Grégory Germain', 'David Cébron']
#  Arxiv
# Week-end Culture - semaine 02, par AutoModerator Nombre de commentaires :9
#  Reddit
# What is the difference between sévice and abus?, par aFilminFrench Nombre de commentaires :11
#  Reddit
# What shuttle goes to courchevel from Geneva airport?, par betterthanlenadunham Nombre de commentaires :1
#  Reddit
# What toppings are there in a French shawarma/kebab?, par aiabdmensl Nombre de commentaires :16
#  Reddit
# Windings of the 2D free Rouse chain, par Olivier Benichou Co-Auteurs : ['Jean Desbois']
#  Arxiv
# Women mathematicians in France in the mid-twentieth century, par Yvette Kosmann-Schwarzbach Co-Auteurs : 0
#  Arxiv
# Would you consider the term "frenchy" offensive?, par ReputableMisfit Nombre de commentaires :14
#  Reddit
# Wronskians and linear independence, par Alin Bostan Co-Auteurs : ['Philippe Dumas']
#  Arxiv
# XIth International Conference on Elastic and Diffractive Scattering in  Chateau de Blois, France, May 15 - 20, 2005. Conference Summary, par Stanley J. Brodsky Co-Auteurs : ['Michael Rijssenbeek']
#  Arxiv
# XMM -Newton observations of merging clusters of galaxies: A3921 and  A1750, par E. Belsole Co-Auteurs : ['J-L. Sauvageot', 'R. Teyssier']
#  Arxiv
# XMM-Newton Observations of Galaxy Clusters: The Radial Temperature  Profile of A2163, par G. W. Pratt Co-Auteurs : ['M. Arnaud', 'N. Aghanim']
#  Arxiv
# Yang-Mills theory and Tamagawa numbers, par Aravind Asok Co-Auteurs : ['Brent Doran', 'Frances Kirwan']
#  Arxiv

# %% [markdown]
# ## Taille du corpus

# %%
print(c.ndoc)
# Out:
# 454

# %% [markdown]
# # Affichage des textes par ordre alphabétique

# %%
c.showDocSortedByTitle(152)
# Out:
# Document: $\mathcal{S}$-adic characterization of minimal dendric shifts - Date: 2022/06/01
# Document: (final) Higgs results from LEP - Date: 2002/05/13
# Document: 26M - Peut on faire un bilan de santé librement ? - Date: 2024/01/06
# Document: 39h sans RTT - Date: 2024/01/04
# Document: 44Ti nucleosynthesis gamma-ray lines with SIMBOL-X - Date: 2007/09/17
# Document: [PC] Aide pour mon Pc. - Date: 2024/01/03
# Document: [slay the spire] la carte "cri de guerre" - Date: 2024/01/03
# Document: [STEAM] Pas l'argent pour son anniversaire, sur quoi me rabattre ? - Date: 2024/01/04
# Document: [Throw Away] Suis-je un alternant empoté ? - Date: 2024/01/05
# Document: A 2.4 - 12 microns spectrophotometric study with ISO of Cygnus X-3 in  quiescence - Date: 2002/07/22
# Document: A Case study of light pollution in France after the change in  legislation - Date: 2020/06/08
# Document: A complex surface admitting a strongly plurisubharmonic function but no  holomorphic functions - Date: 2012/10/30
# Document: A conjectural bound on the second Betti number for hyper-Kähler  manifolds - Date: 2019/09/16
# Document: A Criticism on "A Mathematician's Apology" by G. H. Hardy - Date: 2011/12/19
# Document: A data capture and production management tool for the assembly and  construction of the CMS detectors - Date: 2001/05/18
# Document: A Ferrand-Obata theorem for rank one parabolic geometries - Date: 2006/08/22
# Document: A Fully Coupled Multi-Physics Model to Simulate Phase Change Memory  Operations in Ge-rich Ge$_2$Sb$_2$Te$_5$ Alloys - Date: 2023/09/07
# Document: A Generalization of the Brodsky-Lepage Formalism - Date: 1997/06/13
# Document: A linear programming approach to general dataflow process network  verification and dimensioning - Date: 2010/10/27
# Document: A mathematical explanation via "intelligent" PID controllers of the  strange ubiquity of PIDs - Date: 2010/05/04
# Document: A multifractal random walk - Date: 2000/05/24
# Document: A Multipath Transport Protocol for Future Internet - Date: 2011/12/19
# Document: A new fractional model in Caputo sense for studying the dynamics of  COVID-19 spread in France - Date: 2022/08/11
# Document: A one-channel conductor in an ohmic environment: mapping to a TLL and  full counting statistics - Date: 2003/12/18
# Document: A p-adic Shimura-Maass operator on Mumford curves - Date: 2020/11/10
# Document: A parabolic minimal surface in R3 intersects every nonflat properly  embedded minimal surface of bounded curvature - Date: 2022/06/13
# Document: A properly embedded holomorphic disc in the ball with finite area and  dense boundary curve - Date: 2017/09/04
# Document: A quasi-Kinnersley tetrad for the quasi-Kerr metric - Date: 2006/01/23
# Document: A Review, Framework and R toolkit for Exploring, Evaluating, and  Comparing Visualizations - Date: 2019/02/22
# Document: A sequent calculus with procedure calls - Date: 2012/04/23
# Document: A supervised clustering approach for fMRI-based inference of brain  states - Date: 2011/04/28
# Document: A Visual Analytics Approach to Compare Propagation Models in Social  Networks - Date: 2015/04/10
# Document: A VM-Agnostic and Backwards Compatible Protected Modifier for  Dynamically-Typed Languages - Date: 2023/06/21
# Document: About pseudo-Riemannian Lichnerowicz conjecture - Date: 2012/11/03
# Document: Absolute Branching Ratio of Beta-Delayed Gamma-Ray Emission of N18 - Date: 2003/07/07
# Document: Actions of semisimple Lie groups preserving a degenerate Riemannian  metric - Date: 2007/11/17
# Document: Ad Orientem: the Orientation of Gothic Cathedrals of France - Date: 2012/09/11
# Document: After Sitges - Date: 1999/09/10
# Document: aimez vous manger du cheval ? j'ai l'impression d'être le seul dans toute mes connaissances. juste curieux ! - Date: 2024/01/01
# Document: Aircraft routing and crew pairing: updated algorithms at Air France - Date: 2017/06/21
# Document: Algebraic Change-Point Detection - Date: 2009/12/07
# Document: Aligning component upgrades - Date: 2011/09/01
# Document: Alternative Restart Strategies for CMA-ES - Date: 2012/07/01
# Document: American here, why is there a misconception that French people are mean? - Date: 2024/01/04
# Document: Américain ici: Comme les Jeux Olympiques approchent, je veux que ma soirée de visionnage soit authentiquement française. Des suggestions? - Date: 2024/01/04
# Document: An analysis of Coggia-Couvreur attack on Loidreau's rank-metric public  key encryption scheme in the general case - Date: 2021/12/23
# Document: An interpolation theorem for proper holomorphic embeddings - Date: 2005/11/04
# Document: An Optimised Flow for Futures: From Theory to Practice - Date: 2021/07/15
# Document: Analogies minus analogy test: measuring regularities in word embeddings - Date: 2020/10/07
# Document: Analyzing Flowgraphs with ATL - Date: 2013/12/02
# Document: Anciens anxieux/anxieuses sociaux, quel est le meilleur conseil qu’on vous ai donné ? - Date: 2024/01/03
# Document: API design for machine learning software: experiences from the  scikit-learn project - Date: 2013/09/01
# Document: Appartements en France - Date: 2024/01/06
# Document: Approximation diophantienne et distribution locale sur une surface  torique II - Date: 2018/05/10
# Document: Are X-ray flashes a peculiar class of (soft) gamma-ray bursts ? - Date: 2002/12/02
# Document: Arnaqué dans une boutique de réparation de téléphone - Date: 2024/01/02
# Document: ATLsc with partial observation - Date: 2015/09/24
# Document: Atmospheres from very low-mass stars to extrasolar planets - Date: 2012/06/05
# Document: Audiophile : choix d'ampli et conseils pour la sono de mon séjour. - Date: 2024/01/05
# Document: Avez-vous peur de laisser vos fenêtres ouvertes la nuit ? - Date: 2024/01/02
# Document: Avoir des compétences sociales est tellement plus importants que je ne le pensais - Date: 2024/01/05
# Document: Azimuthal Correlations in Photon-Photon Collisions - Date: 1995/11/23
# Document: Baisse des APL ? - Date: 2024/01/05
# Document: Baugh-Wooley Multiplication for the RISCV Processor - Date: 2023/04/19
# Document: Besoin d'aide pour amplifier mes B&W CDM2 - Date: 2024/01/03
# Document: Besoin d'aide pour divorce. - Date: 2024/01/05
# Document: Best French city to study in and meet new people? - Date: 2024/01/05
# Document: Billet d'avion avec les chèques vacances - Date: 2024/01/03
# Document: Blind separation of noisy Gaussian stationary sources. Application to  cosmic microwave background imaging - Date: 2002/09/23
# Document: Bonjour à tous connaissez-vous un bon avocat ou un juriste svp? - Date: 2024/01/05
# Document: bonjour! question regarding college tuition - Date: 2024/01/04
# Document: Borderline INFP raconte sa vie - Date: 2024/01/03
# Document: Bridge-mediated Donor-Acceptor Effective Coupling: Exact theoretical  description - Date: 2005/02/09
# Document: Bug des caisses automatiques - Date: 2024/01/03
# Document: Camper-van Break-in - Date: 2024/01/03
# Document: Cartan-Kähler Theory and Applications to Local Isometric and Conformal  Embedding - Date: 2013/04/20
# Document: Casorati Determinant Solutions for the Discrete Painlevé-II Equation - Date: 1993/10/20
# Document: Chanteurs Français ou chanteuses Françaises - Date: 2024/01/03
# Document: Characterization of the first true coaxial 18-fold segmented n-type  prototype detector for the GERDA project - Date: 2007/01/04
# Document: Codage arithmetique pour la description d'une distribution - Date: 2007/05/21
# Document: Cohomology of moduli spaces - Date: 2003/05/24
# Document: Colis et douanes — légal ou arnaque ? - Date: 2024/01/06
# Document: Combining sparse grids, multilevel MC and QMC for elliptic PDEs with  random coefficients - Date: 2017/11/07
# Document: Combining Technical and Financial Impacts for Countermeasure Selection - Date: 2014/10/16
# Document: Comment je suis sorti de l'addiction au téléphone. - Date: 2024/01/05
# Document: Comment refuser le small talk ? Des gens comme moi ? - Date: 2024/01/05
# Document: Comment s'améliorer en programmation algorithmique ? - Date: 2024/01/03
# Document: Comment éviter les problématiques de communication avec des collègues ? - Date: 2024/01/04
# Document: Comments on "Factors associated with the spatial heterogeneity of the  first wave of COVID-19 in France: a nationwide geo-epidemiological study" by  Gaudart et al - Date: 2021/03/19
# Document: Comparison between purely statistical and multi-agent based ap-proaches  for occupant behaviour modeling in buildings - Date: 2015/10/08
# Document: Comparison of cuprates and nuclear matter pairing properties. Quartet  (alpha-particle) condensation in nuclear systems - Date: 2018/11/29
# Document: Complete sets of relations in the cohomology rings of moduli spaces of  holomorphic bundles and parabolic bundles over a Riemann surface - Date: 2003/05/24
# Document: Configuration réseau pour un routeur Mikrotik - Date: 2024/01/04
# Document: Configurational Approaches to Urban Form: Empirical Test on the City of  Nice (France) - Date: 2021/11/08
# Document: Conseil lecture code de calcul - Date: 2024/01/03
# Document: Conseil légal - appartement en location sans isolation - quels recours ? - Date: 2024/01/05
# Document: Conseils achat fer à souder - Date: 2024/01/04
# Document: Conseils pour CV - Date: 2024/01/05
# Document: Contract Aware Components, 10 years after - Date: 2010/10/14
# Document: Controllability of the bilinear Schrödinger equation with several  controls and application to a 3D molecule - Date: 2012/04/26
# Document: Cooperative emission in quantum plasmonic superradiance - Date: 2018/10/26
# Document: Correct-by-design Control Synthesis for Multilevel Converters using  State Space Decomposition - Date: 2014/07/15
# Document: Counterfactual Causality from First Principles? - Date: 2017/10/10
# Document: CP parameters of the B systems from Tevatron - Date: 2008/09/17
# Document: CPF / Pôle emploi - Date: 2024/01/05
# Document: Cryptanalysis of public-key cryptosystems that use subcodes of algebraic  geometry codes - Date: 2014/09/29
# Document: CT moto - Date: 2024/01/03
# Document: Dame folle à l’aide - Date: 2024/01/03
# Document: Dark Energy: Beyond General Relativity? - Date: 2006/05/20
# Document: Decorated proofs for computational effects: States - Date: 2011/12/11
# Document: Demander des conseils sur la situation du chauffage - Date: 2024/01/04
# Document: Design and expected performance of the ANTARES neutrino telescope - Date: 2000/01/21
# Document: Detection of Change--Points in the Spectral Density. With Applications  to ECG Data - Date: 2009/01/20
# Document: Deterministic Automata for Unordered Trees - Date: 2014/08/26
# Document: Dielectric constant of glasses: first observation of a two-dimensional  behavior - Date: 2002/10/01
# Document: Diplôme d’école VS titre RNCP - Date: 2024/01/05
# Document: Discrete Breathers and Energy Localization in Nonlinear Lattices - Date: 1993/06/25
# Document: Discussion of "Search for the Wreckage of Air France Flight AF 447" - Date: 2014/05/20
# Document: Distribution of Eigenvalues for the Modular Group - Date: 1995/09/26
# Document: Divisors defined by noncritical functions - Date: 2017/09/15
# Document: Do soda taxes affect the consumption and health of school-aged children?  Evidence from France and Hungary - Date: 2021/11/29
# Document: Double vol de paillasson - Date: 2024/01/05
# Document: Durée de vie d'un disque dur ? - Date: 2024/01/02
# Document: Dégénerescence Locale des Transformations Conformes  pseudo-Riemanniennes - Date: 2010/08/14
# Document: EDF Tarif Bleu ou Zen Flex - Date: 2024/01/05
# Document: Eisenstein Metrics - Date: 2021/08/09
# Document: Element Diffusion and Accretion in Metal Poor Stars - Date: 2011/08/25
# Document: Embeddings of infinitely connected planar domains into C^2 - Date: 2011/10/24
# Document: Encore une panne majeure pour Bouygues dans l'ouest ? - Date: 2024/01/03
# Document: Energy redistribution between quasiparticles in mesoscopic silver wires - Date: 1999/12/08
# Document: Enseigner les équations chimiques aux enfants de 6 ans - Date: 2024/01/06
# Document: Envoyer un médicament par courrier - Date: 2024/01/04
# Document: est-ce que la France est en retard technologiquement? - Date: 2024/01/03
# Document: Est-ce que ça vous fait penser à un symbole nazi ? Moi oui donc j'ai pas trop envie de le coudre mais si ça ce trouve y'a que moi qui pense à ça - Date: 2024/01/05
# Document: Et vos vœux en carte... - Date: 2024/01/03
# Document: Euclidean quadratic forms are ADC forms: A short proof - Date: 2013/10/08
# Document: Every bordered Riemann surface is a complete proper curve in a ball - Date: 2012/07/24
# Document: Evidence for coeval Late Triassic terrestrial impacts from the  Rochechouart (France) meteorite crater - Date: 2007/03/08
# Document: Evolving Genes to Balance a Pole - Date: 2010/05/17
# Document: Exact Random Walk Distributions using Noncommutative Geometry - Date: 1997/08/18
# Document: Existe t'il un sub ou on parle entreprenariat, projet, ou on peut poser des questions et avoir un retour comme sur conseiljuridique ? - Date: 2024/01/05
# Document: Experimental Comparisons of Derivative Free Optimization Algorithms - Date: 2010/05/31
# Document: Exponential functionals of Brownian motion and disordered systems - Date: 1996/01/05
# Document: Extension of the Virasoro and Neveu-Schwartz algebras and generalized  Sturm-Liouville operators - Date: 1996/02/29
# Document: Extraction de concepts sous contraintes dans des données d'expression  de gènes - Date: 2009/02/07
# Document: Fatou-Bieberbach domains in $\mathbb C^n\setminus\mathbb R^k$ - Date: 2014/01/13
# Document: Fibrations and Stein Neighborhoods - Date: 2009/06/12
# Document: Finances personnelles et revenu en cas de mobilisation générale - Date: 2024/01/05
# Document: First and second order optimality conditions for optimal control  problems of state constrained integral equations - Date: 2012/05/16
# Document: Fixed Parameter Undecidability for Wang Tilesets - Date: 2012/08/14
# Document: Flexible Automatic Scheduling For Autonomous Telescopes: The MAJORDOME - Date: 2001/11/05
# Document: Force-velocity relation and density profiles for biased diffusion in an  adsorbed monolayer - Date: 2000/04/26
